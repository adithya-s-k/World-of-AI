# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4747  8884-FEEWR    Male              0      No         No      35
# 1670  5047-LHVLY    Male              1      No        Yes       1
# 5708  7072-MBHEV  Female              1     Yes        Yes      11
# 796   2040-OBMLJ    Male              0      No         No      31
# 2083  4897-QSUYC  Female              0      No         No       1
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 4747          Yes            No              No  No internet service  ...
# 1670          Yes            No             DSL                   No  ...
# 5708          Yes           Yes     Fiber optic                   No  ...
# 796           Yes           Yes     Fiber optic                   No  ...
# 2083          Yes            No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 4747  No internet service  No internet service  No internet service
# 1670                  Yes                   No                   No
# 5708                  Yes                   No                   No
# 796                    No                  Yes                   No
# 2083  No internet service  No internet service  No internet service
#
#           StreamingMovies        Contract PaperlessBilling  \
# 4747  No internet service        One year               No
# 1670                   No  Month-to-month              Yes
# 5708                   No  Month-to-month              Yes
# 796                    No        One year               No
# 2083  No internet service  Month-to-month              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 4747  Bank transfer (automatic)          20.60           754    No
# 1670               Mailed check          50.15         50.15   Yes
# 5708    Credit card (automatic)          78.10        864.85    No
# 796     Credit card (automatic)          81.70       2548.65    No
# 2083               Mailed check          20.15         20.15   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# We don't need the customerID so we can remove it.

# %%
df.drop('customerID', axis='columns', inplace=True)

# %%
#checking if the customerID column is dropped
df.sample(3)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 5158    Male              0      No         No      72          Yes
# 5446    Male              0      No         No       1          Yes
# 5318  Female              0     Yes        Yes      32          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 5158           Yes              No  No internet service  No internet service
# 5446            No              No  No internet service  No internet service
# 5318            No             DSL                  Yes                  Yes
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 5158  No internet service  No internet service  No internet service
# 5446  No internet service  No internet service  No internet service
# 5318                  Yes                  Yes                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 5158  No internet service        Two year               No
# 5446  No internet service  Month-to-month               No
# 5318                  Yes        Two year               No
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 5158  Bank transfer (automatic)           24.75       1777.6    No
# 5446               Mailed check           19.65        19.65   Yes
# 5318               Mailed check           73.60      2316.85    No

# %%
#checking the data-type of the columns
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# We can see from the data types that the TotalCharges is an object whereas MonthlyCharges is in float64

# %%
#checking all the values in the dataframe
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %% [markdown]
# As, we can see these are all strings. We need to convert the strings to numbers.

# %%
#convert the TotalCharges data-type to numeric data-type
pd.to_numeric(df.TotalCharges, errors='coerce')
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %% [markdown]
# Since there were empty strings before, we might have some null figures.

# %%
#checking for null values
pd.to_numeric(df.TotalCharges, errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %% [markdown]
# We cannot see the hidden rows.

# %%
#exploring the hidden rows
df[pd.to_numeric(df.TotalCharges, errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
#shape of the dataframe
df.shape
# Out:
# (7043, 20)

# %% [markdown]
# As we can see there are 11 rows that have no values in the TotalCharges column.

# %%
#looking at the values of specific rows
df.iloc[488]
# Out:
# gender                                 Female
# SeniorCitizen                               0
# Partner                                   Yes
# Dependents                                Yes
# tenure                                      0
# PhoneService                               No
# MultipleLines                No phone service
# InternetService                           DSL
# OnlineSecurity                            Yes
# OnlineBackup                               No
# DeviceProtection                          Yes
# TechSupport                               Yes
# StreamingTV                               Yes
# StreamingMovies                            No
# Contract                             Two year
# PaperlessBilling                          Yes
# PaymentMethod       Bank transfer (automatic)
# MonthlyCharges                          52.55
# TotalCharges
# Churn                                      No
# Name: 488, dtype: object

# %% [markdown]
# We can drop 11 rows out of 7043 rows where the TotalCharges has no value.

# %%
#dropping those rows
df1= df[df.TotalCharges!=' ']
df1.shape
# Out:
# (7032, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#converting TotalCharges data-type from object to numeric
pd.to_numeric(df1.TotalCharges)
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7032, dtype: float64

# %% [markdown]
# Since it is not showing an error, we can store it in the main dataframe.

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_27432\973151263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %% [markdown]
# As we can see, the datatype for TotalCharges is now float64.

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# We need to focus on tenure because tenure means how loyal the customer is.
#
# We need to know how many of the loyal customers are leaving.

# %%
#finding all the customers where Churn=No
#Churn=No means the customer is not leaving
df1[df1.Churn=='No']
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 7037  Female              0      No         No      72          Yes
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 0     No phone service             DSL                   No
# 1                   No             DSL                  Yes
# 3     No phone service             DSL                  Yes
# 6                  Yes     Fiber optic                   No
# 7     No phone service             DSL                  Yes
# ...                ...             ...                  ...
# 7037                No              No  No internet service
# 7038               Yes             DSL                  Yes
# 7039               Yes     Fiber optic                   No
# 7040  No phone service             DSL                  Yes
# 7042                No     Fiber optic                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 0                     Yes                   No                   No
# 1                      No                  Yes                   No
# 3                      No                  Yes                  Yes
# 6                     Yes                   No                   No
# 7                      No                   No                   No
# ...                   ...                  ...                  ...
# 7037  No internet service  No internet service  No internet service
# 7038                   No                  Yes                  Yes
# 7039                  Yes                  Yes                   No
# 7040                   No                   No                   No
# 7042                   No                  Yes                  Yes
#
#               StreamingTV      StreamingMovies        Contract  \
# 0                      No                   No  Month-to-month
# 1                      No                   No        One year
# 3                      No                   No        One year
# 6                     Yes                   No  Month-to-month
# 7                      No                   No  Month-to-month
# ...                   ...                  ...             ...
# 7037  No internet service  No internet service        Two year
# 7038                  Yes                  Yes        One year
# 7039                  Yes                  Yes        One year
# 7040                   No                   No  Month-to-month
# 7042                  Yes                  Yes        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 0                 Yes           Electronic check           29.85
# 1                  No               Mailed check           56.95
# 3                  No  Bank transfer (automatic)           42.30
# 6                 Yes    Credit card (automatic)           89.10
# 7                  No               Mailed check           29.75
# ...               ...                        ...             ...
# 7037              Yes  Bank transfer (automatic)           21.15
# 7038              Yes               Mailed check           84.80
# 7039              Yes    Credit card (automatic)          103.20
# 7040              Yes           Electronic check           29.60
# 7042              Yes  Bank transfer (automatic)          105.65
#
#       TotalCharges Churn
# 0            29.85    No
# 1          1889.50    No
# 3          1840.75    No
# 6          1949.40    No
# 7           301.90    No
# ...            ...   ...
# 7037       1419.40    No
# 7038       1990.50    No
# 7039       7362.90    No
# 7040        346.45    No
# 7042       6844.50    No
#
# [5163 rows x 20 columns]

# %%
#tenure = for how many months are they availing the services
tenure_churn_no = df1[df1.Churn=='No'].tenure
tenure_churn_no
# Out:
# 0        1
# 1       34
# 3       45
# 6       22
# 7       10
#         ..
# 7037    72
# 7038    24
# 7039    72
# 7040    11
# 7042    66
# Name: tenure, Length: 5163, dtype: int64

# %%
#tenure_churn_yes= the customers who availed the services but left
tenure_churn_yes = df1[df1.Churn=='Yes'].tenure
tenure_churn_yes
# Out:
# 2        2
# 4        2
# 5        8
# 8       28
# 13      49
#         ..
# 7021    12
# 7026     9
# 7032     1
# 7034    67
# 7041     4
# Name: tenure, Length: 1869, dtype: int64

# %%
plt.hist([tenure_churn_yes, tenure_churn_no], color=['green', 'red'], label=['Churn=Yes', 'Churn=No'])
plt.legend()

#giving the axis labels
plt.xlabel("Tenure")
plt.ylabel("Number of customers")
plt.title("Customer Churn Prediction Visualization")
# Out:
# Text(0.5, 1.0, 'Customer Churn Prediction Visualization')

# %%
mc_churn_no = df1[df1.Churn=='No'].MonthlyCharges
mc_churn_yes = df1[df1.Churn=='Yes'].MonthlyCharges

# %%
plt.hist([mc_churn_yes, mc_churn_no], color=['green', 'red'], label=['Churn=Yes', 'Churn=No'])
plt.legend()

#giving the axis labels
plt.xlabel("Monthly Charges")
plt.ylabel("Number of customers")
plt.title("Customer Churn Prediction Visualization")
# Out:
# Text(0.5, 1.0, 'Customer Churn Prediction Visualization')

# %% [markdown]
# As we can see the customers are leaving more.

# %% [markdown]
# ### Label Encoding

# %%
df1
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 0                 Yes           Electronic check           29.85
# 1                  No               Mailed check           56.95
# 2                 Yes               Mailed check           53.85
# 3                  No  Bank transfer (automatic)           42.30
# 4                 Yes           Electronic check           70.70
# ...               ...                        ...             ...
# 7038              Yes               Mailed check           84.80
# 7039              Yes    Credit card (automatic)          103.20
# 7040              Yes           Electronic check           29.60
# 7041              Yes               Mailed check           74.40
# 7042              Yes  Bank transfer (automatic)          105.65
#
#       TotalCharges Churn
# 0            29.85    No
# 1          1889.50    No
# 2           108.15   Yes
# 3          1840.75    No
# 4           151.65   Yes
# ...            ...   ...
# 7038       1990.50    No
# 7039       7362.90    No
# 7040        346.45    No
# 7041        306.60   Yes
# 7042       6844.50    No
#
# [7032 rows x 20 columns]

# %% [markdown]
# As we can see, lot of columns have yes/no value so we need to do label encoding.

# %%
for column in df:
    print(column)
# Out:
# gender
# SeniorCitizen
# Partner
# Dependents
# tenure
# PhoneService
# MultipleLines
# InternetService
# OnlineSecurity
# OnlineBackup
# DeviceProtection
# TechSupport
# StreamingTV
# StreamingMovies
# Contract
# PaperlessBilling
# PaymentMethod
# MonthlyCharges
# TotalCharges
# Churn

# %%
#printing unique values in each of the column
def print_unique_col_values(df):
       for column in df:
            if df[column].dtypes=='object':
                print(f'{column}: {df[column].unique()}')

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %% [markdown]
# Some of the columns have no internet service or no phone service which can be replaced by a simple no.

# %%
df1.replace('No internet service','No',inplace=True)
df1.replace('No phone service','No',inplace=True)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_27432\2045096646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service','No',inplace=True)
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_27432\2045096646.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service','No',inplace=True)

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %% [markdown]
# Performing one hot encoding to convert the yes/no to 1/0

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df1[col].replace({'Yes': 1,'No': 0},inplace=True)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_27432\1648037665.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({'Yes': 1,'No': 0},inplace=True)

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df1['gender'].replace({'Female':1,'Male':0},inplace=True)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_27432\698335744.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
df1.gender.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract','PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 4423       0              0        0           0      33             1
# 4879       1              1        0           0      46             1
# 6743       0              0        0           0      10             1
# 1715       1              0        1           1      46             1
# 5920       1              1        0           0      26             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 4423              0               0             1                 1  ...
# 4879              1               0             0                 1  ...
# 6743              1               0             0                 0  ...
# 1715              0               0             0                 0  ...
# 5920              0               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 4423                    1                            0                   0
# 4879                    1                            0                   0
# 6743                    0                            0                   1
# 1715                    0                            0                   1
# 5920                    0                            1                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 4423                        1                  0                  0
# 4879                        0                  1                  0
# 6743                        1                  0                  0
# 1715                        0                  0                  1
# 5920                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 4423                                        0
# 4879                                        0
# 6743                                        0
# 1715                                        0
# 5920                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 4423                                      1                               0
# 4879                                      1                               0
# 6743                                      0                               1
# 1715                                      0                               0
# 5920                                      0                               1
#
#       PaymentMethod_Mailed check
# 4423                           0
# 4879                           0
# 6743                           0
# 1715                           1
# 5920                           0
#
# [5 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %% [markdown]
# As we can see, we have converted the categorical data to numeric data.

# %% [markdown]
# ### Minmax Scaling

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges: [0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %% [markdown]
# ### Train-Test Split

# %%
X = df2.drop('Churn',axis='columns')
y = df2['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (5625, 26)

# %%
X_test.shape
# Out:
# (1407, 26)

# %%
X_train[:10]
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5664       1              1        0           0  0.126761             1
# 101        1              0        1           1  0.000000             1
# 2621       0              0        1           0  0.985915             1
# 392        1              1        0           0  0.014085             1
# 1327       0              0        1           0  0.816901             1
# 3607       1              0        0           0  0.169014             1
# 2773       0              0        1           0  0.323944             0
# 1936       1              0        1           0  0.704225             1
# 5387       0              0        0           0  0.042254             0
# 4331       0              0        0           0  0.985915             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5664              0               0             0                 1  ...
# 101               0               0             0                 0  ...
# 2621              0               0             1                 1  ...
# 392               0               0             0                 0  ...
# 1327              1               0             0                 1  ...
# 3607              0               1             0                 0  ...
# 2773              0               0             0                 1  ...
# 1936              0               1             1                 0  ...
# 5387              0               0             0                 0  ...
# 4331              1               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5664                    0                            1                   0
# 101                     0                            0                   1
# 2621                    1                            0                   0
# 392                     1                            0                   0
# 1327                    0                            1                   0
# 3607                    1                            0                   0
# 2773                    1                            0                   0
# 1936                    1                            0                   0
# 5387                    1                            0                   0
# 4331                    0                            0                   1
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5664                        1                  0                  0
# 101                         1                  0                  0
# 2621                        0                  0                  1
# 392                         1                  0                  0
# 1327                        0                  1                  0
# 3607                        0                  1                  0
# 2773                        1                  0                  0
# 1936                        0                  1                  0
# 5387                        1                  0                  0
# 4331                        0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5664                                        0
# 101                                         0
# 2621                                        0
# 392                                         0
# 1327                                        1
# 3607                                        0
# 2773                                        0
# 1936                                        1
# 5387                                        0
# 4331                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5664                                      1                               0
# 101                                       0                               1
# 2621                                      1                               0
# 392                                       0                               1
# 1327                                      0                               0
# 3607                                      0                               0
# 2773                                      0                               1
# 1936                                      0                               0
# 5387                                      0                               1
# 4331                                      0                               0
#
#       PaymentMethod_Mailed check
# 5664                           0
# 101                            0
# 2621                           0
# 392                            0
# 1327                           0
# 3607                           1
# 2773                           0
# 1936                           0
# 5387                           0
# 4331                           0
#
# [10 rows x 26 columns]

# %%
len(X_train.columns)
# Out:
# 26

# %% [markdown]
# ### Building an ANN model

# %%
import tensorflow as tf
from tensorflow import keras


model = keras.Sequential([
    keras.layers.Dense(26, input_shape=(26,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# opt = keras.optimizers.Adam(learning_rate=0.01)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 2ms/step - loss: 0.4715 - accuracy: 0.7726
# Epoch 2/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4261 - accuracy: 0.7943
# Epoch 3/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4203 - accuracy: 0.7968
# Epoch 4/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4157 - accuracy: 0.8011
# Epoch 5/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4130 - accuracy: 0.8055
# Epoch 6/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4107 - accuracy: 0.8052
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4089 - accuracy: 0.8066
# Epoch 8/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4068 - accuracy: 0.8060
# Epoch 9/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4062 - accuracy: 0.8076
# Epoch 10/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4047 - accuracy: 0.8085
# Epoch 11/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4038 - accuracy: 0.8055
# Epoch 12/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4039 - accuracy: 0.8094
# Epoch 13/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4012 - accuracy: 0.8114
# Epoch 14/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4004 - accuracy: 0.8135
# Epoch 15/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3999 - accuracy: 0.8091
# Epoch 16/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3984 - accuracy: 0.8140
# Epoch 17/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3977 - accuracy: 0.8142
# Epoch 18/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3970 - accuracy: 0.8114
# Epoch 19/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3959 - accuracy: 0.8140
# Epoch 20/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3956 - accuracy: 0.8158
# Epoch 21/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8165
# Epoch 22/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3937 - accuracy: 0.8162
# Epoch 23/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3928 - accuracy: 0.8160
# Epoch 24/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3920 - accuracy: 0.8178
# Epoch 25/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3924 - accuracy: 0.8171
# Epoch 26/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3909 - accuracy: 0.8137
# Epoch 27/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3901 - accuracy: 0.8185
# Epoch 28/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3889 - accuracy: 0.8169
# Epoch 29/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3888 - accuracy: 0.8197
# Epoch 30/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3860 - accuracy: 0.8204
# Epoch 31/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3870 - accuracy: 0.8188
# Epoch 32/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3858 - accuracy: 0.8190
# Epoch 33/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3848 - accuracy: 0.8181
# Epoch 34/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3838 - accuracy: 0.8187
# Epoch 35/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3839 - accuracy: 0.8169
# Epoch 36/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3818 - accuracy: 0.8220
# Epoch 37/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3824 - accuracy: 0.8160
# Epoch 38/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3823 - accuracy: 0.8208
# Epoch 39/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3806 - accuracy: 0.8203
# Epoch 40/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3810 - accuracy: 0.8240
# Epoch 41/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3809 - accuracy: 0.8203
# Epoch 42/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3793 - accuracy: 0.8206
# Epoch 43/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3799 - accuracy: 0.8183
# Epoch 44/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3787 - accuracy: 0.8197
# Epoch 45/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3781 - accuracy: 0.8201
# Epoch 46/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3771 - accuracy: 0.8236
# Epoch 47/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3769 - accuracy: 0.8244
# Epoch 48/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3753 - accuracy: 0.8229
# Epoch 49/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3764 - accuracy: 0.8224
# Epoch 50/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3746 - accuracy: 0.8245
# Epoch 51/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3751 - accuracy: 0.8229
# Epoch 52/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3742 - accuracy: 0.8252
# Epoch 53/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3733 - accuracy: 0.8228
# Epoch 54/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3726 - accuracy: 0.8252
# Epoch 55/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3724 - accuracy: 0.8226
# Epoch 56/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3712 - accuracy: 0.8240
# Epoch 57/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3718 - accuracy: 0.8236
# Epoch 58/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3713 - accuracy: 0.8267
# Epoch 59/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3704 - accuracy: 0.8267
# Epoch 60/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3699 - accuracy: 0.8265
# Epoch 61/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3684 - accuracy: 0.8276
# Epoch 62/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3698 - accuracy: 0.8254
# Epoch 63/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3693 - accuracy: 0.8290
# Epoch 64/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3684 - accuracy: 0.8258
# Epoch 65/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3678 - accuracy: 0.8249
# Epoch 66/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3672 - accuracy: 0.8276
# Epoch 67/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3651 - accuracy: 0.8299
# Epoch 68/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3664 - accuracy: 0.8263
# Epoch 69/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3655 - accuracy: 0.8260
# Epoch 70/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3650 - accuracy: 0.8272
# Epoch 71/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3666 - accuracy: 0.8270
# Epoch 72/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3657 - accuracy: 0.8279
# Epoch 73/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3646 - accuracy: 0.8302
# Epoch 74/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3631 - accuracy: 0.8297
# Epoch 75/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3648 - accuracy: 0.8306
# Epoch 76/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3635 - accuracy: 0.8286
# Epoch 77/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3641 - accuracy: 0.8297
# Epoch 78/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3636 - accuracy: 0.8320
# Epoch 79/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3622 - accuracy: 0.8302
# Epoch 80/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3622 - accuracy: 0.8304
# Epoch 81/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3616 - accuracy: 0.8327
# Epoch 82/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3612 - accuracy: 0.8311
# Epoch 83/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3609 - accuracy: 0.8316
# Epoch 84/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3601 - accuracy: 0.8324
# Epoch 85/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3597 - accuracy: 0.8315
# Epoch 86/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3608 - accuracy: 0.8316
# Epoch 87/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3590 - accuracy: 0.8345
# Epoch 88/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3579 - accuracy: 0.8320
# Epoch 89/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3585 - accuracy: 0.8329
# Epoch 90/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3586 - accuracy: 0.8332
# Epoch 91/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3572 - accuracy: 0.8329
# Epoch 92/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3575 - accuracy: 0.8331
# Epoch 93/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3568 - accuracy: 0.8341
# Epoch 94/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3563 - accuracy: 0.8350
# Epoch 95/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3575 - accuracy: 0.8332
# Epoch 96/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3562 - accuracy: 0.8336
# Epoch 97/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3566 - accuracy: 0.8324
# Epoch 98/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3556 - accuracy: 0.8325
# Epoch 99/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3548 - accuracy: 0.8357
# Epoch 100/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3558 - accuracy: 0.8347

# %%
#printing the accuracy of the model
model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4786 - accuracy: 0.7711
# [0.47859904170036316, 0.7711442708969116]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# 44/44 [==============================] - 0s 2ms/step
# array([[0.3462226 ],
#        [0.6524506 ],
#        [0.00826158],
#        [0.8929128 ],
#        [0.4561972 ]], dtype=float32)

# %%
#conveting the sigmoid to 0 or 1
#less than 0.5=0
#more than 0.5=1
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [0, 1, 0, 1, 0, 1, 0, 1, 0, 0]

# %%
y_test[:10]
# Out:
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# 816     1
# 2670    0
# 5920    0
# 1023    0
# 6087    0
# Name: Churn, dtype: int64
